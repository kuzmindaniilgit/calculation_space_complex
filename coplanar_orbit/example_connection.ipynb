# %% [markdown]
# # Связь классов модуля

# %%
from orbitpy import *

# %%
ic = IntegrationConstants(1500, -6700, -7900, -8, -1, 1)
ic.find()
# Out:
# Константы найдены (см. документацию)!
# Основные константы интегрирования (h, p, e, i, Omega, tpi):
# (-10.16599134946891,
#  17702.107375815354,
#  0.7406221357027162,
#  2.2862363238910923,
#  3.3739476567867843,
#  None)

# %%
p = ic.p
e = ic.e
tj = Trajectory()
tj.polar(p, e)

# %%
vect = ic.to_2D()
r = vect[0]
v = vect[1]

# %%
tj = Trajectory(0, 405)
tj.spacecraft(20_000, 15_000, 20, 3)
tj.trajectory(r[0], r[1], v[0], v[1])
tj.plot()
