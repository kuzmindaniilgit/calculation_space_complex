# %%
from orbitpy import *

# %%
ic = IntegrationConstants(1500, -6700, -7900, -8, -1, 1)
ic.find()

i, omega, Omega, p, e = ic.i, ic.omega, ic.Omega, ic.p, ic.e
# Out:
# Константы найдены (см. документацию)!
# Основные константы интегрирования (h, p, e, i, Omega, tpi):
# -10.16599134946891 17702.107375815354 0.7406221357027162 2.2862363238910923 3.3739476567867843 None

# %%
tj = Trajectory()
tj.orbit3d(i, omega, Omega, p, e, vertical_roll=0, z_roll=30)
